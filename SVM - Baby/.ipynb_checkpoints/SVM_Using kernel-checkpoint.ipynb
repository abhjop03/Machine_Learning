# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_circles

# %%
data, labels = make_circles(1000, noise=0.1,  factor=0.2)

# %%
plt.scatter(data[:, 0], data[:, 1], c=labels)

# %%
# Let convert the daya 2D data into 3D data
x = data[:,0].reshape(-1, 1)
y = data[:,1].reshape(-1, 1)
axis_3 = x**2+y**2

# %%
dataset = np.hstack((data, axis_3))

# %%
ax = plt.subplot(projection = '3d')
ax.scatter(x,y,axis_3,c=labels)

# %%
from sklearn import svm

# %%
svm_classifier = svm.SVC(kernel = 'linear', degree =2)

# %%
svm_classifier.fit(dataset, labels)
# Out:
# SVC(degree=2, kernel='linear')

# %%
svm_classifier.score(dataset, labels)
# Out:
# 1.0

# %%
weights = svm_classifier.coef_
bias = svm_classifier.intercept_

# %%
weights
# Out:
# array([[-0.10241672,  0.00466058, -4.38751658]])

# %%
a = np.array([1,2,3,4,5])
print(a.shape)
b = np.array([3,4,5,6,7])
print(a.shape)
# Out:
# (5,)
# (5,)

# %%
a,b = np.meshgrid(a,b)
print(a.shape, b.shape)
# Out:
# (5, 5) (5, 5)

# %%
mesh_x, mesh_y = np.meshgrid(dataset[:, 0], dataset[:,1] )

# %%
mesh_x.shape
# Out:
# (1000, 1000)

# %%
plane = -(weights[0,0] * mesh_x + weights[0,1] * mesh_y + bias[0])/weights[0,2]

# %%
ax = plt.subplot(projection = '3d')
ax.scatter(x,y,axis_3,c=labels)
ax.plot_surface(mesh_x, mesh_y, plane)
